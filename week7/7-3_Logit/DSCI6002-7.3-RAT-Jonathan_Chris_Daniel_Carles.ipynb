# %% [markdown]
# # RAT 7.3
#
# We have seasonal quarterly financial data from Johnson and Johnson 1960-1981 in https://s3-us-west-2.amazonaws.com/dsci/6002/data/jj.txt
#
# 1) Plot the time series data.

# %%
# %pylab inline

import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
jj = pd.read_csv('https://s3-us-west-2.amazonaws.com/dsci/6002/data/jj.txt')
jj.head()
# Out:
#    earnings
# 0      0.71
# 1      0.63
# 2      0.85
# 3      0.44
# 4      0.61

# %%
jj.describe()
# Out:
#         earnings
# count  84.000000
# mean    4.799762
# std     4.309991
# min     0.440000
# 25%     1.247500
# 50%     3.510000
# 75%     7.132500
# max    16.200000

# %%
len(jj)
# Out:
# 84

# %%
jj['time'] = range(1,len(jj)+1)
jj.head()
# Out:
#    earnings  time
# 0      0.71     1
# 1      0.63     2
# 2      0.85     3
# 3      0.44     4
# 4      0.61     5

# %%
jj['time'] = pd.Series()

# %%
jj.earnings.plot();

# %% [markdown]
# 2) What do you see in the plot? (Trend, seasonality...)

# %% [markdown]
# The trend is increasing earnings over time.

# %% [markdown]
# 3) BONUS: Modify the data to make it approximately stationary.

# %%
jj['log_earning'] = log(jj.earnings)

# %%
jj.log_earning.plot();

# %% [markdown]
# 4) BONUS: Plot the ACF and PACF of the modified data.

# %%
plot_acf(jj['log_earning'], lags=36, zero=False);

# %%
plot_pacf(jj['log_earning'], lags=36, zero=False);
